# %% [markdown]
# <a href="https://colab.research.google.com/github/reefwn/manning-live-project/blob/main/getting-started-with-google-colab-using-tensorflow/workflow-3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### 1. Open a Notebook you worked on during this liveProject.

# %% [markdown]
# #### 2. If you haven’t registered at GitHub yet, register now and sign in. If you are already registered, then sign in to your account.

# %% [markdown]
# #### 3. Maybe you have already noticed that class definitions pop up whenever you hover over a class in a Colab code cell. Also, part of the code gets highlighted. Hold the Ctrl key, and click on the highlighted area. As a result the source code of the highlighted area will be displayed on the right side of the notebook.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### 4. Create an empty repository on GitHub. Name it to whatever you want.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### 5. Go back to your Colab notebook. Go to **File > Save a copy in GitHub**. Select the name of the repo you created on GitHub to store your Colab notebooks and hit **OK**.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### 6. Your Colab Notebook is available on GitHub if you click on the "Open in Colab" badge.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### 7. Save all your Notebooks into your GitHub repo.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### 8. If you are a Google Chrome User, the [Open in Colab extension](https://chrome.google.com/webstore/detail/open-in-colab/iogfkhleblhcpcekbiedikdehleodpjo) can be handy, since it lets you open GitHub hosted Jupyter notebooks in Colab. This means it lets you open Jupyter notebooks without having the Open in Colab badge. Find an interesting Jupyter Notebook on GitHub, or check out one of our favorite ones [here](https://github.com/SeongokRyu/Graph-neural-networks/blob/master/tutorials/gcn_classification.ipynb).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### 9. By using the Open in Colab extension, open the Jupyter Notebook in Colab. Save a copy of it into your project folder on Google Drive. Finally, save the Notebook on GitHub too.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### 10. If you are a Google Chrome user, you can use the script from [this resource](https://stackoverflow.com/a/63521453) to keep connected to your Colab Notebook. Ctrl + Shift + I opens the Developer Tools. Go to console and paste the code into the console. This code will hit the comment button every 60 second, so your notebook won’t be disconnected. Now, you can run your experiments during nights, or you can work on other things while your experiments run. Be careful, since Colab doesn’t guarantee that your Colab is available for 12 hours. It can cut off your processes earlier, so it is vitally important to save your data and models - with their checkpoints - regularly. Also, save your work on your notebooks (Ctrl + s) from time to time.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ```javascript
# function ClickConnect(){
#   console.log("Working");
#   document.querySelector("#comments > span").click()
# }
# setInterval(ClickConnect,5000)
# ```

# %% [markdown]
# #### 11. If you work with larger datasets, reading from an external storage can be slow. Uploading your files to the virtual machines (VM) makes read time slower. Also, you can save any intermediate files to your local machine, which can be downloaded later on. However, files on the VM have a short life. If you get disconnected, they get deleted. So, save your work and your data on a regular basis.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### 12. Before you end up having Untitled_200.ipynb in your folder on Google Drive, try out the [Colab Scrachpad](https://colab.research.google.com/notebooks/empty.ipynb). Save it to your drive. This way, you get a Notebook which is not automatically saved, so you can use it to try out code snippets.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### 13. Use TensorBoard in your notebooks. TensorFlow comes with TensorBoard, and it is also available in `torch.utils` too. You should add a callback function to log losses during epochs and other data. Add a callback function to the training of the neural network. Save your notebook on Google Drive and on GitHub.

# %% [markdown]
# ```python
# # tensorboard example:
# model = create_model()
# model.compile(optimizer='adam',
#               loss='sparse_categorical_crossentropy',
#               metrics=['accuracy'])
#
# log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
# tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)
#
# model.fit(x=x_train,
#           y=y_train,
#           epochs=5,
#           validation_data=(x_test, y_test),
#           callbacks=[tensorboard_callback])
# ```

# %% [markdown]
# ```python
# # troch.utils example:
# from torch.utils.tensorboard import SummaryWriter
# import numpy as np
#
# writer = SummaryWriter()
#
# for n_iter in range(100):
#     writer.add_scalar('Loss/train', np.random.random(), n_iter)
#     writer.add_scalar('Loss/test', np.random.random(), n_iter)
#     writer.add_scalar('Accuracy/train', np.random.random(), n_iter)
#     writer.add_scalar('Accuracy/test', np.random.random(), n_iter)
# ```

# %% [markdown]
# #### References:
# 1. https://www.tensorflow.org/tensorboard/get_started
# 2. https://pytorch.org/docs/stable/tensorboard.html
